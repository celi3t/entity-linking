# %% [markdown]
# ### Simulate entities for matching

# %% [markdown]
# Simulate 2 datasets:
#
# * a "baseline" dataset, for matching a dataset with itself. We are using the trivial dataset for end-to-end smoke tests.
# * a regular dataset, that simulates possible issues with mismatching entity data across datasets

# %%
from faker import Faker
import random
import json
import pandas as pd
import numpy as np
import re
import datetime as dt

# %% [markdown]
# Fields to simulate:
# * person internal_id
# * service date
# * person first name(s), last name(s), middle name(s)
# * person dob
# * person ssn
# * person address st, city, postal code, state (always CA)
# * person phone number

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Trivial simulation

# %%
def create_persons(n_people):
    persons = []
    faker = Faker()
    for p in range(n_people):
        person = {}
        person["person_id"] = p + 1000
        
        person_service_date_shift = random.randint(30, 500)
        person["service_date"] = dt.date.today() - dt.timedelta(days=person_service_date_shift)
        person["first_name"] = faker.first_name()
        person["middle_name"] = faker.first_name()
        person["last_name"] = faker.last_name()
        person['dob'] = person["service_date"] - dt.timedelta(days=random.randint(366*18, 366*60))
        
        person["ssn"] = faker.ssn()
        person["street_address"] = faker.address()
        person["city"] = faker.city()
        person["zip"] = faker.postcode()
        person["state"] = "CA"
        person["phone"] = faker.phone_number()
        
        persons.append(person)
        
    return persons

# %%
#create_persons(10)

# %% [markdown]
# #### Non-trivial simulation

# %% [markdown]
# Here, we create the same person twice, with mismatching information. The output will be two "people lists": ListX and ListY
#
# Possible mismatches:
# * two last names in listX, only 1 last name in listY
# * middle name as first name
# * address changed
# * phone number changed
# * typo in names
# * mismatching special characters in names (e.g. Smith-Lewis vs Smith Lewis)
# * Shortened names, nicknames instead of names (e.g. Kat vs Katherine)

# %% [markdown]
# Thanks to [this project](https://github.com/carltonnorthern/nickname-and-diminutive-names-lookup) we have a csv of names and similar names to draw from for the simulation

# %%
# TODO: be smarter about this function
def insert_typo(name):
    if "i" in name:
        name = name.replace("i", "y")
    elif "o" in name:
        name = name.replace("o", "p")
    return name

# %%
names = pd.read_csv('names_lookup.csv' , header = None, delimiter = ";")
names["first"] = names[0].apply(lambda x: x.split(",")[0])
names["nicknames"] = names[0].apply(lambda x: x.split(",")[1:])
names.head(5)
# Out:
#                                      0     first  \
# 0                aaron,erin,ronnie,ron     aaron
# 1  abbigail,nabby,abby,gail,abbi,abbey  abbigail
# 2                      abednego,bedney  abednego
# 3                 abel,ebbie,ab,abe,eb      abel
# 4                             abiel,ab     abiel
#
#                           nicknames
# 0               [erin, ronnie, ron]
# 1  [nabby, abby, gail, abbi, abbey]
# 2                          [bedney]
# 3              [ebbie, ab, abe, eb]
# 4                              [ab]

# %%
count_names_lookup = len(names)

# %%
def create_persons_datasets(n_people):
    ### Probabilities for whether to introduce a person variation or not:
    perc_first_name_mismatch = 0.5
    perc_double_last_name_mismatch = 0.2
    perc_middle_name_as_first_name = 0.1
    perc_missing_ssn = 0.1
    perc_typo = 0.3
    persons_x = []
    persons_y = []
    faker = Faker()
    for p in range(n_people):
        person_x = {}
        person_y = {}
        person_x["person_id"] = p + 1000
        person_y["person_id"] = person_x["person_id"]
        person_service_date_shift = random.randint(30, 500)
        person_x["service_date"] = dt.date.today() - dt.timedelta(days=person_service_date_shift)
        person_y["service_date"] = person_x["service_date"]
        
        same_name = bool(np.random.choice(np.arange(2), p=[perc_first_name_mismatch, (1-perc_first_name_mismatch)]))
        
        if same_name:
            person_x["first_name"] = faker.first_name()
            person_y["first_name"] = person_x["first_name"]
        else:
            #use nicknames lookup, random sample a name, and then sample a nickname for that row/name
            person_x["first_name"] = names["first"].iloc[np.random.choice(count_names_lookup+1)]
            person_y["first_name"] = names.loc[names['first'] == person_x["first_name"], "nicknames"].apply(lambda x: x[np.random.choice(np.arange(len(x)))]).values[0]

        person_x["middle_name"] = faker.first_name()
        person_x["last_name"] = faker.last_name()
        person_x['dob'] = person_x["service_date"] - dt.timedelta(days=random.randint(366*18, 366*60))
        
        person_y["middle_name"] = person_x["middle_name"]
        
        person_y["last_name"] = person_x["last_name"]
        double_last_name_mismatch = bool(np.random.choice(np.arange(2), p=[(1-perc_double_last_name_mismatch), perc_double_last_name_mismatch]))
        if double_last_name_mismatch:
            person_y["last_name"] = person_y["last_name"] + " " + faker.last_name()
        
        person_y['dob'] = person_x['dob']
        
        person_x["ssn"] = faker.ssn()
        ssn_missing = bool(np.random.choice(np.arange(2), p=[(1-perc_missing_ssn), perc_missing_ssn]))
        if ssn_missing:
            person_y["ssn"] = ''
        else:
            person_y["ssn"] = person_x["ssn"]
#         person["street_address"] = faker.address()
#         person["city"] = faker.city()
#         person["zip"] = faker.postcode()
#         person["state"] = "CA"
#         person["phone"] = faker.phone_number()
        
        persons_x.append(person_x)
        persons_y.append(person_y)
        
    return persons_x, persons_y

# %% [markdown]
# ### Example dataset creation:

# %%
people1, people2 = create_persons_datasets(26)

# %%
people1 = pd.DataFrame(people1)
people1
# Out:
#     person_id service_date first_name middle_name last_name         dob  \
# 0        1000   2020-10-20      vicky       Kathy     Singh  1984-04-01
# 1        1001   2021-09-06       Gary      Stacey    Watson  1984-10-22
# 2        1002   2020-11-07       Anna      Joseph   Camacho  1996-04-11
# 3        1003   2021-10-24       Rose      Amanda    Powers  1989-12-27
# 4        1004   2020-12-26    Rebecca      Steven    Zuniga  1962-03-10
# 5        1005   2021-08-10      trudy       James      Sims  1986-08-10
# 6        1006   2020-11-07      lucas      Dustin   Mccarty  1985-09-19
# 7        1007   2021-10-21     Marcus      Dustin      Frye  1998-02-21
# 8        1008   2021-05-09       John       Brian     Brown  1990-02-26
# 9        1009   2021-01-06     Tracey       Devin     Adams  1961-09-24
# 10       1010   2020-09-20  Gabrielle     Kristin     Baker  1974-03-12
# 11       1011   2021-06-04       Kyle     Madison     Potts  1992-09-02
# 12       1012   2021-07-07     tobias    Nicholas    Harris  1999-12-14
# 13       1013   2020-10-12   kathleen      Dillon    Duncan  1977-07-10
# 14       1014   2021-05-12       rich     Yolanda    Wright  1969-11-08
# 15       1015   2021-02-17    Timothy      Joseph    Dodson  1981-11-03
# 16       1016   2020-11-24        bab      Joshua      Wise  1971-12-26
# 17       1017   2021-10-27       Lisa        Tina  Thompson  1980-12-16
# 18       1018   2021-01-27    Rebecca       Lydia   Bentley  1983-03-14
# 19       1019   2021-01-27   avarilla    Michelle    Benton  1961-09-10
# 20       1020   2021-05-28      chick      Walter  Mckenzie  1997-03-11
# 21       1021   2021-04-13      Terri      Sharon      Webb  1995-03-29
# 22       1022   2021-08-17      aleva     Rebekah    Decker  1971-10-28
# 23       1023   2021-10-16       Greg       Emily   Wiggins  1999-03-10
# 24       1024   2021-04-21     Angela       Ariel    Torres  1997-11-01
# 25       1025   2021-11-13       Kyle       Riley      Pace  1990-02-22
#
#             ssn
# 0   895-37-4654
# 1   220-72-9331
# 2   404-44-6841
# 3   072-45-6710
# 4   624-34-0417
# 5   594-16-0019
# 6   287-46-6447
# 7   696-12-9088
# 8   456-39-7324
# 9   459-84-2417
# 10  274-78-7065
# 11  775-04-0217
# 12  292-82-5257
# 13  323-96-8830
# 14  847-46-2572
# 15  172-53-0064
# 16  235-33-8539
# 17  061-81-9889
# 18  266-71-2424
# 19  073-05-7081
# 20  827-82-7571
# 21  436-02-8463
# 22  554-02-4122
# 23  205-88-9464
# 24  433-11-6545
# 25  164-37-0280

# %%
people2 = pd.DataFrame(people2)
people2
# Out:
#     person_id service_date first_name middle_name         last_name  \
# 0        1000   2020-10-20   victoria       Kathy             Singh
# 1        1001   2021-09-06       Gary      Stacey    Watson Shaffer
# 2        1002   2020-11-07       Anna      Joseph           Camacho
# 3        1003   2021-10-24       Rose      Amanda            Powers
# 4        1004   2020-12-26    Rebecca      Steven    Zuniga Stevens
# 5        1005   2021-08-10   gertrude       James              Sims
# 6        1006   2020-11-07       luke      Dustin           Mccarty
# 7        1007   2021-10-21     Marcus      Dustin     Frye Atkinson
# 8        1008   2021-05-09       John       Brian       Brown Blake
# 9        1009   2021-01-06     Tracey       Devin             Adams
# 10       1010   2020-09-20  Gabrielle     Kristin             Baker
# 11       1011   2021-06-04       Kyle     Madison             Potts
# 12       1012   2021-07-07       toby    Nicholas            Harris
# 13       1013   2020-10-12        kay      Dillon            Duncan
# 14       1014   2021-05-12       dick     Yolanda            Wright
# 15       1015   2021-02-17    Timothy      Joseph            Dodson
# 16       1016   2020-11-24      barby      Joshua              Wise
# 17       1017   2021-10-27       Lisa        Tina     Thompson Case
# 18       1018   2021-01-27    Rebecca       Lydia           Bentley
# 19       1019   2021-01-27      rilla    Michelle       Benton Mora
# 20       1020   2021-05-28      chuck      Walter  Mckenzie Harrell
# 21       1021   2021-04-13      Terri      Sharon              Webb
# 22       1022   2021-08-17       levy     Rebekah            Decker
# 23       1023   2021-10-16       Greg       Emily           Wiggins
# 24       1024   2021-04-21     Angela       Ariel    Torres Stevens
# 25       1025   2021-11-13       Kyle       Riley              Pace
#
#            dob          ssn
# 0   1984-04-01  895-37-4654
# 1   1984-10-22  220-72-9331
# 2   1996-04-11
# 3   1989-12-27  072-45-6710
# 4   1962-03-10  624-34-0417
# 5   1986-08-10
# 6   1985-09-19  287-46-6447
# 7   1998-02-21  696-12-9088
# 8   1990-02-26  456-39-7324
# 9   1961-09-24  459-84-2417
# 10  1974-03-12  274-78-7065
# 11  1992-09-02  775-04-0217
# 12  1999-12-14  292-82-5257
# 13  1977-07-10  323-96-8830
# 14  1969-11-08  847-46-2572
# 15  1981-11-03
# 16  1971-12-26  235-33-8539
# 17  1980-12-16  061-81-9889
# 18  1983-03-14  266-71-2424
# 19  1961-09-10  073-05-7081
# 20  1997-03-11  827-82-7571
# 21  1995-03-29  436-02-8463
# 22  1971-10-28  554-02-4122
# 23  1999-03-10  205-88-9464
# 24  1997-11-01  433-11-6545
# 25  1990-02-22  164-37-0280

# %%
people1.to_csv('../simulated_data/dataset_1.csv', index = False)

# %%
people2.to_csv('../simulated_data/dataset_2.csv', index = False)
